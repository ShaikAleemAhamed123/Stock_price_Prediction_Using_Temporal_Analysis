# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# !pip install yfinance
import yfinance as yf

from datetime import datetime



end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)

apple = yf.download("AAPL", start, end)
# Out:
# Requirement already satisfied: yfinance in c:\users\shaik\anaconda3\lib\site-packages (0.2.28)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.31 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pytz>=2022.5 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shaik\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\shaik\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\shaik\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shaik\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# [*********************100%%**********************]  1 of 1 completed

# %%
apple.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    115.651069   117.017255   114.369551   115.749620   114.332679
# std      46.956414    47.438170    46.489623    46.972990    47.259623
# min      35.994999    36.430000    35.500000    35.547501    34.163834
# 25%      65.940001    66.846249    65.550001    66.406248    64.780319
# 50%     128.728745   130.339996   126.970001   128.855003   126.740231
# 75%     152.205002   154.210003   150.377502   152.362495   151.252548
# max     196.240005   198.229996   195.279999   196.449997   196.185074
#
#              Volume
# count  1.258000e+03
# mean   1.075482e+08
# std    5.459865e+07
# min    3.145820e+07
# 25%    7.225568e+07
# 50%    9.302575e+07
# 75%    1.268662e+08
# max    4.265100e+08

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2018-09-24 to 2023-09-22
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB

# %%
plt.figure(figsize=(15, 10))

apple['Adj Close'].plot()
plt.ylabel('Adj Close')
plt.xlabel(None)
plt.title(f"Closing Price of Apple")
plt.legend()
plt.tight_layout()

# %%
# Now let's plot the total volume of stock being traded each day
plt.figure(figsize=(15, 10))

apple['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title(f"Sales Volume for Apple")
plt.legend()
plt.tight_layout()

# %%
ma_day = [50, 200]

for ma in ma_day:
        column_name = f"{ma}_DMA"
        apple[column_name] = apple['Adj Close'].rolling(ma).mean()

plt.figure(figsize=(15, 10))
apple['50_DMA'].plot()
apple['200_DMA'].plot()
apple['Adj Close'].plot()
plt.ylabel('Moving Average')
plt.xlabel("Year")
plt.title("50 DMA Vs 200 DMA of \"APPLE\"")
plt.legend()
plt.tight_layout()

# %%
apple['Down_Cross'] = ((apple['50_DMA']< apple['200_DMA']) & 
                       (apple['50_DMA'].shift(1) > apple['200_DMA'].shift(1))).astype(int)
apple['Up_Cross'] = ((apple['50_DMA']> apple['200_DMA']) & 
                       (apple['50_DMA'].shift(1) < apple['200_DMA'].shift(1))).astype(int)

# %%
apple['CrossOver']=(apple["Down_Cross"]+apple["Up_Cross"]>=1).astype(int)
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-09-24   54.205002   55.314999   54.157501   55.197498   52.864510
# 2018-09-25   54.937500   55.705002   54.924999   55.547501   53.199711
# 2018-09-26   55.250000   55.937500   54.939999   55.105000   52.775909
# 2018-09-27   55.955002   56.610001   55.884998   56.237499   53.860558
# 2018-09-28   56.197498   56.459999   56.005001   56.435001   54.049702
# ...                ...         ...         ...         ...         ...
# 2023-09-18  176.479996  179.380005  176.169998  177.970001  177.970001
# 2023-09-19  177.520004  179.630005  177.130005  179.070007  179.070007
# 2023-09-20  179.259995  179.699997  175.399994  175.490005  175.490005
# 2023-09-21  174.550003  176.300003  173.860001  173.929993  173.929993
# 2023-09-22  174.669998  177.078995  174.054993  174.789993  174.789993
#
#                Volume      50_DMA     200_DMA  Down_Cross  Up_Cross  CrossOver
# Date
# 2018-09-24  110773600         NaN         NaN           0         0          0
# 2018-09-25   98217600         NaN         NaN           0         0          0
# 2018-09-26   95938800         NaN         NaN           0         0          0
# 2018-09-27  120724800         NaN         NaN           0         0          0
# 2018-09-28   91717600         NaN         NaN           0         0          0
# ...               ...         ...         ...         ...       ...        ...
# 2023-09-18   67257600  184.342663  164.564343           0         0          0
# 2023-09-19   51826900  184.156950  164.722687           0         0          0
# 2023-09-20   58436200  183.910222  164.861737           0         0          0
# 2023-09-21   63047900  183.598541  164.995477           0         0          0
# 2023-09-22   55110610  183.288680  165.139392           0         0          0
#
# [1258 rows x 11 columns]

# %% [markdown]
# # Using Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
data=apple;
data.dropna(inplace=True)
y = data['CrossOver']
data.drop(['Down_Cross','Up_Cross','CrossOver'], axis=1)
X=data
 
 

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# Create and train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred=model.predict(X_test)
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.9962264150943396

# %% [markdown]
# # Prophet Model

# %%
# !pip install yfinance
# !pip install prophet
# Out:
# Requirement already satisfied: yfinance in c:\users\shaik\anaconda3\lib\site-packages (0.2.28)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: requests>=2.31 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pytz>=2022.5 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\shaik\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shaik\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\shaik\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\shaik\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shaik\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaik\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: prophet in c:\users\shaik\anaconda3\lib\site-packages (1.1.4)
# Requirement already satisfied: holidays>=0.25 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (0.33)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (3.5.1)
# Requirement already satisfied: importlib-resources in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (6.1.0)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (1.21.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (1.1.0)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (4.64.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\shaik\anaconda3\lib\site-packages (from prophet) (1.4.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\shaik\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\shaik\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in c:\users\shaik\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2023.3.post1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shaik\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\shaik\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\shaik\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shaik\anaconda3\lib\site-packages (from importlib-resources->prophet) (3.7.0)

# %%
# Fetch historical data
from matplotlib import dates as mdates
stock_symbol = 'AAPL'
end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)
df = yf.download(stock_symbol, start=start, end=end)

# Calculate the 50DMA and 200DMA
df['50DMA'] = df['Close'].rolling(window=50).mean()
df['200DMA'] = df['Close'].rolling(window=200).mean()
df['diff']=df['50DMA']-df['200DMA']

# Create a DataFrame with 'ds' (datestamp) and 'y' (the difference between 50DMA and 200DMA)
df = df.reset_index()  # Reset the index to access the 'Date' column
df = df[['Date', 'diff']].rename(columns={'Date': 'ds', 'diff': 'y'}).dropna()
df
# Create and fit the Prophet model
model = Prophet()
model.fit(df)

# Create a future DataFrame
future = model.make_future_dataframe(periods=30, freq='D')  # Extend 30 days into the future

# Make predictions
forecast = model.predict(future)


# Plot the forecast
plt.figure(figsize=(15, 10))
ax = plt.subplot(1, 1, 1)

# Plot the forecast within the same subplot using the 'ax' parameter
model.plot(forecast, ax=ax)

# Customize plot properties (title, legend, etc.)
plt.title('Golden Crossover Prediction with Prophet')
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 01:01:24 - cmdstanpy - INFO - Chain [1] start processing
# 01:01:24 - cmdstanpy - INFO - Chain [1] done processing
