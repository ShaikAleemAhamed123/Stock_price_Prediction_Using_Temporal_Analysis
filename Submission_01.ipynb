# %%
# !pip install yfinance
from datetime import datetime

# %%
import yfinance as yf
end=datetime.now()
start=datetime(end.year, end.month-1,end.day)
apple_stock=yf.download("AAPL",start,end)
apple_stock.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
# 2023-08-18  172.300003  175.100006  171.960007  174.490005  174.490005
#
#               Volume
# Date
# 2023-08-14  43675600
# 2023-08-15  43622600
# 2023-08-16  46964900
# 2023-08-17  66062900
# 2023-08-18  61114200

# %%
window_size = 3
apple_stock['SMA_3'] = apple_stock['Close'].rolling(window=window_size).mean()

# %%
apple_stock.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
# 2023-08-18  172.300003  175.100006  171.960007  174.490005  174.490005
#
#               Volume       SMA_3
# Date
# 2023-08-14  43675600         NaN
# 2023-08-15  43622600         NaN
# 2023-08-16  46964900  177.826670
# 2023-08-17  66062900  176.006668
# 2023-08-18  61114200  175.020004

# %%
apple_stock['EMA_3'] = apple_stock['Close'].ewm(span=window_size, adjust=False).mean()
apple_stock.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-14  177.970001  179.690002  177.309998  179.460007  179.460007
# 2023-08-15  178.880005  179.479996  177.050003  177.449997  177.449997
# 2023-08-16  177.130005  178.539993  176.500000  176.570007  176.570007
# 2023-08-17  177.139999  177.509995  173.479996  174.000000  174.000000
# 2023-08-18  172.300003  175.100006  171.960007  174.490005  174.490005
#
#               Volume       SMA_3       EMA_3
# Date
# 2023-08-14  43675600         NaN  179.460007
# 2023-08-15  43622600         NaN  178.455002
# 2023-08-16  46964900  177.826670  177.512505
# 2023-08-17  66062900  176.006668  175.756252
# 2023-08-18  61114200  175.020004  175.123129

# %%
# !pip install TA-Lib
import talib
# Out:
# ...
#   Using cached TA-Lib-0.4.28.tar.gz (357 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
# Failed to build TA-Lib
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\shaik\anaconda3\python.exe' 'C:\Users\shaik\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\shaik\AppData\Local\Temp\tmpzyu7nqn6'
#        cwd: C:\Users\shaik\AppData\Local\Temp\pip-install-5zkuztar\ta-lib_1779c2e0a8ca4f2ba70d773e50f22270
#   Complete output (14 lines):
#   <string>:77: UserWarning: Cannot find ta-lib library, installation may fail.
# ...

# %%
import numpy as np
close_prices = np.array(df['Close'])
apple_stocks['RSI']=talib.RSI(close_prices)
apple_stocks.head()
